# %%
import sys
import os

from train_lstm import train_lstm_model

print("Training and validation metrics for TSLA: High Volatility")
train_lstm_model('JNJ')
train_lstm_model('NVDA')
train_lstm_model('JPM')
train_lstm_model('XOM')
train_lstm_model('AMZN')
train_lstm_model('NKE')
train_lstm_model('LMT')
# Out:
# Training and validation metrics for TSLA: High Volatility
# /Users/adrianpawlowski/Documents/AITradingPlatform/ML/lstm/../data_processing.py:209: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data[features] = data[features].fillna(method='ffill').fillna(method='bfill').fillna(0)
# 2025-04-03 15:59:47.190067: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2025-04-03 15:59:47.190085: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2025-04-03 15:59:47.190090: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2025-04-03 15:59:47.190103: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...
