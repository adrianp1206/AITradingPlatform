# %%
from genetic_algorithm import genetic_algorithm
from train_boost import train_xgboost

# Define parameters
tickers = ['TSLA', 'AMZN']
start_date = '2008-01-01'
end_date = '2021-12-31'
all_features = [
    'BB_upper', 'BB_middle', 'BB_lower', 'DEMA', 'MIDPOINT', 'MIDPRICE', 'SMA', 'T3',
    'TEMA', 'TRIMA', 'WMA', 'ADX', 'ADXR', 'APO', 'AROON_DOWN', 'AROON_UP', 'AROONOSC',
    'CCI', 'CMO', 'MACD', 'MACD_signal', 'MACD_hist', 'MFI', 'MINUS_DI', 'MINUS_DM', 'MOM',
    'PLUS_DI', 'PLUS_DM', 'ROC', 'RSI', 'STOCH_slowk', 'STOCH_slowd', 'STOCH_fastk',
    'STOCH_fastd', 'ATR', 'NATR', 'TRANGE', 'AD', 'ADOSC', 'OBV', 'AVGPRICE', 'MEDPRICE',
    'TYPPRICE', 'WCLPRICE', 'HT_DCPERIOD', 'HT_DCPHASE', 'HT_PHASOR_inphase',
    'HT_PHASOR_quadrature', 'HT_SINE', 'HT_LEADSINE', 'HT_TRENDMODE'
]

# XGBoost parameters
xgb_params = {
    'learning_rate': 0.1,
    'n_estimators': 200,
    'max_depth': 4
}

# Run loop over each ticker
for ticker in tickers:
    print(f"\n📈 Running GA and XGBoost for: {ticker}")

    try:
        # Step 1: Run Genetic Algorithm to find best features
        best_features = genetic_algorithm(ticker, start_date, end_date, all_features)
        print(f"✅ Best features for {ticker}: {best_features}")

        # Step 2: Train XGBoost using selected features
        final_metrics, _ = train_xgboost(
            ticker=ticker,
            start_date=start_date,
            end_date=end_date,
            feature_subset=best_features,
            params=xgb_params,
            save_model=True
        )

        # Step 3: Display only relevant metrics
        parsed_metrics = {
            key: final_metrics[key]
            for key in ['accuracy', 'precision', 'recall', 'f1_score', 'roc_auc']
        }
        print(f"📊 Final Metrics for {ticker}: {parsed_metrics}")

    except Exception as e:
        print(f"❌ Error processing {ticker}: {e}")
# Out:
# 📈 Running GA and XGBoost for: TSLA
# Generation 1
# Cross-validation metrics:
# accuracy: 0.4944
# precision: 0.5189
# recall: 0.2978
# f1_score: 0.3651
# roc_auc: 0.5119
# Cross-validation metrics:
# accuracy: 0.4996
# precision: 0.5526
# recall: 0.3292
# f1_score: 0.3828
# roc_auc: 0.5122
# Cross-validation metrics:
# accuracy: 0.4902
# precision: 0.5327
# recall: 0.3001
# f1_score: 0.3707
# roc_auc: 0.5138
# Cross-validation metrics:
# accuracy: 0.4910
# precision: 0.5356
# recall: 0.3602
# f1_score: 0.4158
# roc_auc: 0.4894
# Cross-validation metrics:
# accuracy: 0.5056
# precision: 0.5403
# recall: 0.4283
# f1_score: 0.4709
# roc_auc: 0.5142
# Cross-validation metrics:
# accuracy: 0.4966
# precision: 0.5396
# recall: 0.3467
# f1_score: 0.3995
# roc_auc: 0.5030
# Cross-validation metrics:
# accuracy: 0.4863
# precision: 0.5192
# recall: 0.3186
# f1_score: 0.3766
# roc_auc: 0.4999
# Cross-validation metrics:
# accuracy: 0.4940
# precision: 0.5315
# recall: 0.3063
# f1_score: 0.3745
# roc_auc: 0.5205
# Cross-validation metrics:
# accuracy: 0.4932
# precision: 0.5376
# recall: 0.3297
# f1_score: 0.3877
# roc_auc: 0.5177
# Cross-validation metrics:
# accuracy: 0.4944
# precision: 0.5281
# recall: 0.3697
# f1_score: 0.4115
# roc_auc: 0.5096
# Generation 2
# Cross-validation metrics:
# accuracy: 0.4936
# precision: 0.5207
# recall: 0.4606
# f1_score: 0.4733
# roc_auc: 0.5092
# Cross-validation metrics:
# accuracy: 0.5004
# precision: 0.5408
# recall: 0.3469
# f1_score: 0.3961
# roc_auc: 0.5178
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5357
# recall: 0.4027
# f1_score: 0.4453
# roc_auc: 0.5129
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5476
# recall: 0.3768
# f1_score: 0.4248
# roc_auc: 0.5208
# Cross-validation metrics:
# accuracy: 0.4932
# precision: 0.5192
# recall: 0.4050
# f1_score: 0.4272
# roc_auc: 0.5008
# Cross-validation metrics:
# accuracy: 0.4940
# precision: 0.5251
# recall: 0.4013
# f1_score: 0.4512
# roc_auc: 0.5060
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5501
# recall: 0.3499
# f1_score: 0.4053
# roc_auc: 0.5134
# Cross-validation metrics:
# accuracy: 0.4872
# precision: 0.5249
# recall: 0.2737
# f1_score: 0.3349
# roc_auc: 0.5149
# Cross-validation metrics:
# accuracy: 0.4970
# precision: 0.5336
# recall: 0.3914
# f1_score: 0.4364
# roc_auc: 0.5036
# Cross-validation metrics:
# accuracy: 0.4983
# precision: 0.5356
# recall: 0.4201
# f1_score: 0.4478
# roc_auc: 0.5191
# Generation 3
# Cross-validation metrics:
# accuracy: 0.4953
# precision: 0.5362
# recall: 0.3750
# f1_score: 0.4229
# roc_auc: 0.5033
# Cross-validation metrics:
# accuracy: 0.4949
# precision: 0.5392
# recall: 0.3732
# f1_score: 0.4114
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.4953
# precision: 0.5314
# recall: 0.3944
# f1_score: 0.4309
# roc_auc: 0.5188
# Cross-validation metrics:
# accuracy: 0.4932
# precision: 0.5331
# recall: 0.4266
# f1_score: 0.4461
# roc_auc: 0.4992
# Cross-validation metrics:
# accuracy: 0.4940
# precision: 0.5407
# recall: 0.3532
# f1_score: 0.3967
# roc_auc: 0.5109
# Cross-validation metrics:
# accuracy: 0.4953
# precision: 0.5460
# recall: 0.3654
# f1_score: 0.4049
# roc_auc: 0.5035
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5439
# recall: 0.4518
# f1_score: 0.4840
# roc_auc: 0.5102
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5466
# recall: 0.3827
# f1_score: 0.4166
# roc_auc: 0.5193
# Cross-validation metrics:
# accuracy: 0.4936
# precision: 0.5364
# recall: 0.3781
# f1_score: 0.4104
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.4983
# precision: 0.5319
# recall: 0.3825
# f1_score: 0.4255
# roc_auc: 0.5178
# Generation 4
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5341
# recall: 0.3972
# f1_score: 0.4334
# roc_auc: 0.5058
# Cross-validation metrics:
# accuracy: 0.4940
# precision: 0.5293
# recall: 0.3683
# f1_score: 0.4047
# roc_auc: 0.5046
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5606
# recall: 0.3730
# f1_score: 0.4105
# roc_auc: 0.5210
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5423
# recall: 0.3912
# f1_score: 0.4494
# roc_auc: 0.5176
# Cross-validation metrics:
# accuracy: 0.4897
# precision: 0.5317
# recall: 0.3913
# f1_score: 0.4242
# roc_auc: 0.4993
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5465
# recall: 0.3907
# f1_score: 0.4545
# roc_auc: 0.5174
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5348
# recall: 0.3726
# f1_score: 0.4139
# roc_auc: 0.5096
# Cross-validation metrics:
# accuracy: 0.5081
# precision: 0.5454
# recall: 0.4672
# f1_score: 0.4865
# roc_auc: 0.5106
# Cross-validation metrics:
# accuracy: 0.4915
# precision: 0.5201
# recall: 0.3978
# f1_score: 0.4418
# roc_auc: 0.5094
# Cross-validation metrics:
# accuracy: 0.4932
# precision: 0.5343
# recall: 0.3809
# f1_score: 0.4146
# roc_auc: 0.5129
# Generation 5
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5369
# recall: 0.3930
# f1_score: 0.4405
# roc_auc: 0.5193
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5487
# recall: 0.4255
# f1_score: 0.4578
# roc_auc: 0.5270
# Cross-validation metrics:
# accuracy: 0.4970
# precision: 0.5240
# recall: 0.4528
# f1_score: 0.4843
# roc_auc: 0.5027
# Cross-validation metrics:
# accuracy: 0.4944
# precision: 0.5287
# recall: 0.3575
# f1_score: 0.3969
# roc_auc: 0.5058
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5414
# recall: 0.3873
# f1_score: 0.4472
# roc_auc: 0.5185
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5341
# recall: 0.3972
# f1_score: 0.4334
# roc_auc: 0.5058
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5423
# recall: 0.3912
# f1_score: 0.4494
# roc_auc: 0.5176
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5606
# recall: 0.3730
# f1_score: 0.4105
# roc_auc: 0.5210
# Cross-validation metrics:
# accuracy: 0.4902
# precision: 0.5211
# recall: 0.4268
# f1_score: 0.4535
# roc_auc: 0.5042
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5465
# recall: 0.3907
# f1_score: 0.4545
# roc_auc: 0.5174
# Generation 6
# Cross-validation metrics:
# accuracy: 0.4953
# precision: 0.5254
# recall: 0.3820
# f1_score: 0.4331
# roc_auc: 0.5037
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5362
# recall: 0.3831
# f1_score: 0.4422
# roc_auc: 0.5059
# Cross-validation metrics:
# accuracy: 0.5021
# precision: 0.5433
# recall: 0.3776
# f1_score: 0.4102
# roc_auc: 0.5173
# Cross-validation metrics:
# accuracy: 0.4863
# precision: 0.5167
# recall: 0.3694
# f1_score: 0.4243
# roc_auc: 0.5006
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5423
# recall: 0.3912
# f1_score: 0.4494
# roc_auc: 0.5176
# Cross-validation metrics:
# accuracy: 0.4987
# precision: 0.5294
# recall: 0.4203
# f1_score: 0.4658
# roc_auc: 0.5068
# Cross-validation metrics:
# accuracy: 0.4966
# precision: 0.5383
# recall: 0.3746
# f1_score: 0.4094
# roc_auc: 0.5190
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5534
# recall: 0.3841
# f1_score: 0.4241
# roc_auc: 0.5263
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5318
# recall: 0.4121
# f1_score: 0.4550
# roc_auc: 0.5002
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5483
# recall: 0.4184
# f1_score: 0.4514
# roc_auc: 0.5226
# Generation 7
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5423
# recall: 0.4235
# f1_score: 0.4515
# roc_auc: 0.5065
# Cross-validation metrics:
# accuracy: 0.5004
# precision: 0.5402
# recall: 0.3869
# f1_score: 0.4265
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5593
# recall: 0.4163
# f1_score: 0.4502
# roc_auc: 0.5234
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5534
# recall: 0.3841
# f1_score: 0.4241
# roc_auc: 0.5263
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5454
# recall: 0.3635
# f1_score: 0.4239
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.4957
# precision: 0.5286
# recall: 0.3722
# f1_score: 0.4257
# roc_auc: 0.5064
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5325
# recall: 0.4462
# f1_score: 0.4842
# roc_auc: 0.5055
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5505
# recall: 0.3792
# f1_score: 0.4271
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5483
# recall: 0.4184
# f1_score: 0.4514
# roc_auc: 0.5226
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5409
# recall: 0.3774
# f1_score: 0.4377
# roc_auc: 0.5124
# Generation 8
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5483
# recall: 0.4184
# f1_score: 0.4514
# roc_auc: 0.5226
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5497
# recall: 0.4689
# f1_score: 0.4836
# roc_auc: 0.5243
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5356
# recall: 0.4108
# f1_score: 0.4400
# roc_auc: 0.5084
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5452
# recall: 0.4302
# f1_score: 0.4585
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.4957
# precision: 0.5286
# recall: 0.3722
# f1_score: 0.4257
# roc_auc: 0.5064
# Cross-validation metrics:
# accuracy: 0.4932
# precision: 0.5216
# recall: 0.4078
# f1_score: 0.4464
# roc_auc: 0.4999
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5505
# recall: 0.3792
# f1_score: 0.4271
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5288
# recall: 0.4342
# f1_score: 0.4708
# roc_auc: 0.5082
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5421
# recall: 0.4252
# f1_score: 0.4713
# roc_auc: 0.5130
# Generation 9
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5452
# recall: 0.4302
# f1_score: 0.4585
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5421
# recall: 0.4252
# f1_score: 0.4713
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5308
# recall: 0.3830
# f1_score: 0.4230
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.5009
# precision: 0.5361
# recall: 0.4272
# f1_score: 0.4573
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5505
# recall: 0.3792
# f1_score: 0.4271
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5483
# recall: 0.4184
# f1_score: 0.4514
# roc_auc: 0.5226
# Cross-validation metrics:
# accuracy: 0.4974
# precision: 0.5253
# recall: 0.3947
# f1_score: 0.4252
# roc_auc: 0.5151
# Cross-validation metrics:
# accuracy: 0.5171
# precision: 0.5443
# recall: 0.5005
# f1_score: 0.5117
# roc_auc: 0.5210
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5521
# recall: 0.3570
# f1_score: 0.3977
# roc_auc: 0.5346
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Generation 10
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5308
# recall: 0.3830
# f1_score: 0.4230
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5004
# precision: 0.5296
# recall: 0.4899
# f1_score: 0.4898
# roc_auc: 0.5137
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5497
# recall: 0.4689
# f1_score: 0.4836
# roc_auc: 0.5243
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5421
# recall: 0.4252
# f1_score: 0.4713
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5536
# recall: 0.3597
# f1_score: 0.4108
# roc_auc: 0.5126
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5361
# recall: 0.4340
# f1_score: 0.4557
# roc_auc: 0.5209
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5618
# recall: 0.3689
# f1_score: 0.4120
# roc_auc: 0.5273
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5505
# recall: 0.3792
# f1_score: 0.4271
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Generation 11
# Cross-validation metrics:
# accuracy: 0.4957
# precision: 0.5187
# recall: 0.4060
# f1_score: 0.4469
# roc_auc: 0.5033
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5386
# recall: 0.4263
# f1_score: 0.4714
# roc_auc: 0.5123
# Cross-validation metrics:
# accuracy: 0.4987
# precision: 0.5238
# recall: 0.4368
# f1_score: 0.4661
# roc_auc: 0.5073
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5399
# recall: 0.4481
# f1_score: 0.4751
# roc_auc: 0.5275
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5421
# recall: 0.4252
# f1_score: 0.4713
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5308
# recall: 0.3830
# f1_score: 0.4230
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5296
# recall: 0.4385
# f1_score: 0.4752
# roc_auc: 0.5096
# Generation 12
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5386
# recall: 0.4263
# f1_score: 0.4714
# roc_auc: 0.5123
# Cross-validation metrics:
# accuracy: 0.4957
# precision: 0.5187
# recall: 0.4060
# f1_score: 0.4469
# roc_auc: 0.5033
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.4996
# precision: 0.5226
# recall: 0.4592
# f1_score: 0.4838
# roc_auc: 0.5107
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5308
# recall: 0.3830
# f1_score: 0.4230
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.5030
# precision: 0.5270
# recall: 0.4412
# f1_score: 0.4680
# roc_auc: 0.5074
# Cross-validation metrics:
# accuracy: 0.5034
# precision: 0.5355
# recall: 0.4242
# f1_score: 0.4547
# roc_auc: 0.5174
# Generation 13
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.4983
# precision: 0.5208
# recall: 0.4639
# f1_score: 0.4791
# roc_auc: 0.5016
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5399
# recall: 0.4481
# f1_score: 0.4751
# roc_auc: 0.5275
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5386
# recall: 0.4263
# f1_score: 0.4714
# roc_auc: 0.5123
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5324
# recall: 0.4814
# f1_score: 0.5009
# roc_auc: 0.5085
# Generation 14
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5410
# recall: 0.4731
# f1_score: 0.4936
# roc_auc: 0.5175
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5305
# recall: 0.5165
# f1_score: 0.5083
# roc_auc: 0.5152
# Cross-validation metrics:
# accuracy: 0.5077
# precision: 0.5328
# recall: 0.4525
# f1_score: 0.4840
# roc_auc: 0.5135
# Cross-validation metrics:
# accuracy: 0.5141
# precision: 0.5362
# recall: 0.4937
# f1_score: 0.5083
# roc_auc: 0.5213
# Generation 15
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5389
# recall: 0.4153
# f1_score: 0.4594
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5253
# recall: 0.4545
# f1_score: 0.4865
# roc_auc: 0.5059
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5320
# recall: 0.4081
# f1_score: 0.4511
# roc_auc: 0.5106
# Cross-validation metrics:
# accuracy: 0.5154
# precision: 0.5444
# recall: 0.4966
# f1_score: 0.5106
# roc_auc: 0.5243
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Generation 16
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5381
# recall: 0.4445
# f1_score: 0.4562
# roc_auc: 0.5113
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5009
# precision: 0.5392
# recall: 0.4152
# f1_score: 0.4503
# roc_auc: 0.5098
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5009
# precision: 0.5337
# recall: 0.4862
# f1_score: 0.4791
# roc_auc: 0.5082
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5365
# recall: 0.4615
# f1_score: 0.4833
# roc_auc: 0.5194
# Generation 17
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5009
# precision: 0.5242
# recall: 0.4480
# f1_score: 0.4693
# roc_auc: 0.4949
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5362
# recall: 0.4589
# f1_score: 0.4696
# roc_auc: 0.5076
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5427
# recall: 0.4543
# f1_score: 0.4810
# roc_auc: 0.5176
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.4966
# precision: 0.5273
# recall: 0.3785
# f1_score: 0.4317
# roc_auc: 0.5155
# Generation 18
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5457
# recall: 0.4529
# f1_score: 0.4705
# roc_auc: 0.5170
# Cross-validation metrics:
# accuracy: 0.5009
# precision: 0.5227
# recall: 0.4689
# f1_score: 0.4898
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5150
# precision: 0.5459
# recall: 0.4980
# f1_score: 0.4845
# roc_auc: 0.5110
# Cross-validation metrics:
# accuracy: 0.5021
# precision: 0.5356
# recall: 0.4445
# f1_score: 0.4624
# roc_auc: 0.5117
# Generation 19
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5073
# precision: 0.5392
# recall: 0.4652
# f1_score: 0.4737
# roc_auc: 0.5112
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5056
# precision: 0.5364
# recall: 0.4730
# f1_score: 0.4700
# roc_auc: 0.5170
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5412
# recall: 0.4379
# f1_score: 0.4672
# roc_auc: 0.5224
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5303
# recall: 0.4587
# f1_score: 0.4633
# roc_auc: 0.5099
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5387
# recall: 0.4410
# f1_score: 0.4632
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5347
# recall: 0.4276
# f1_score: 0.4645
# roc_auc: 0.5085
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Generation 20
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5474
# recall: 0.4734
# f1_score: 0.4752
# roc_auc: 0.5087
# Cross-validation metrics:
# accuracy: 0.5184
# precision: 0.5461
# recall: 0.4854
# f1_score: 0.4917
# roc_auc: 0.5229
# Cross-validation metrics:
# accuracy: 0.5154
# precision: 0.5589
# recall: 0.4642
# f1_score: 0.4825
# roc_auc: 0.5168
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5332
# recall: 0.4839
# f1_score: 0.4996
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5471
# recall: 0.4744
# f1_score: 0.4806
# roc_auc: 0.5112
# Cross-validation metrics:
# accuracy: 0.4987
# precision: 0.5239
# recall: 0.4588
# f1_score: 0.4648
# roc_auc: 0.5049
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5481
# recall: 0.4641
# f1_score: 0.4818
# roc_auc: 0.5272
# Generation 21
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5000
# precision: 0.5251
# recall: 0.4730
# f1_score: 0.4724
# roc_auc: 0.5106
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5400
# recall: 0.4784
# f1_score: 0.4777
# roc_auc: 0.5071
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5355
# recall: 0.4498
# f1_score: 0.4654
# roc_auc: 0.5189
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5385
# recall: 0.4156
# f1_score: 0.4561
# roc_auc: 0.5218
# Cross-validation metrics:
# accuracy: 0.4966
# precision: 0.5377
# recall: 0.4140
# f1_score: 0.4426
# roc_auc: 0.5118
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5432
# recall: 0.4438
# f1_score: 0.4614
# roc_auc: 0.5157
# Generation 22
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5399
# recall: 0.4481
# f1_score: 0.4751
# roc_auc: 0.5275
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5344
# recall: 0.4598
# f1_score: 0.4831
# roc_auc: 0.5064
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5432
# recall: 0.4438
# f1_score: 0.4614
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5450
# recall: 0.4136
# f1_score: 0.4514
# roc_auc: 0.5143
# Cross-validation metrics:
# accuracy: 0.5000
# precision: 0.5251
# recall: 0.4730
# f1_score: 0.4724
# roc_auc: 0.5106
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5355
# recall: 0.4498
# f1_score: 0.4654
# roc_auc: 0.5189
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Generation 23
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5399
# recall: 0.4481
# f1_score: 0.4751
# roc_auc: 0.5275
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5389
# recall: 0.4716
# f1_score: 0.4987
# roc_auc: 0.5195
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5337
# recall: 0.4192
# f1_score: 0.4626
# roc_auc: 0.5025
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5432
# recall: 0.4438
# f1_score: 0.4614
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5021
# precision: 0.5315
# recall: 0.4160
# f1_score: 0.4554
# roc_auc: 0.4979
# Generation 24
# Cross-validation metrics:
# accuracy: 0.5013
# precision: 0.5312
# recall: 0.4718
# f1_score: 0.4662
# roc_auc: 0.5076
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5094
# precision: 0.5421
# recall: 0.4924
# f1_score: 0.4978
# roc_auc: 0.5182
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5459
# recall: 0.4561
# f1_score: 0.4739
# roc_auc: 0.5041
# Cross-validation metrics:
# accuracy: 0.5192
# precision: 0.5494
# recall: 0.5019
# f1_score: 0.5059
# roc_auc: 0.5206
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5412
# recall: 0.4615
# f1_score: 0.4818
# roc_auc: 0.5092
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5384
# recall: 0.4428
# f1_score: 0.4679
# roc_auc: 0.5101
# Cross-validation metrics:
# accuracy: 0.4957
# precision: 0.5266
# recall: 0.4183
# f1_score: 0.4548
# roc_auc: 0.5028
# Generation 25
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.4974
# precision: 0.5174
# recall: 0.4798
# f1_score: 0.4956
# roc_auc: 0.5052
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5472
# recall: 0.4524
# f1_score: 0.4749
# roc_auc: 0.5124
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5233
# recall: 0.4853
# f1_score: 0.5023
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5021
# precision: 0.5370
# recall: 0.4476
# f1_score: 0.4637
# roc_auc: 0.5152
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5280
# recall: 0.4660
# f1_score: 0.4908
# roc_auc: 0.5130
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5329
# recall: 0.4799
# f1_score: 0.4831
# roc_auc: 0.5131
# Cross-validation metrics:
# accuracy: 0.5192
# precision: 0.5494
# recall: 0.5019
# f1_score: 0.5059
# roc_auc: 0.5206
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5371
# recall: 0.4859
# f1_score: 0.4778
# roc_auc: 0.5171
# Generation 26
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5434
# recall: 0.4589
# f1_score: 0.4746
# roc_auc: 0.5231
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5296
# recall: 0.4385
# f1_score: 0.4752
# roc_auc: 0.5096
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5466
# recall: 0.5013
# f1_score: 0.5104
# roc_auc: 0.5243
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5471
# recall: 0.4630
# f1_score: 0.4731
# roc_auc: 0.5190
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5397
# recall: 0.4359
# f1_score: 0.4501
# roc_auc: 0.5215
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5128
# precision: 0.5474
# recall: 0.4815
# f1_score: 0.4923
# roc_auc: 0.5177
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5452
# recall: 0.4478
# f1_score: 0.4695
# roc_auc: 0.5123
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5472
# recall: 0.4524
# f1_score: 0.4749
# roc_auc: 0.5124
# Generation 27
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5558
# recall: 0.4457
# f1_score: 0.4618
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5192
# precision: 0.5529
# recall: 0.4896
# f1_score: 0.5059
# roc_auc: 0.5306
# Cross-validation metrics:
# accuracy: 0.5175
# precision: 0.5491
# recall: 0.4723
# f1_score: 0.4981
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5369
# recall: 0.4508
# f1_score: 0.4605
# roc_auc: 0.5111
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5472
# recall: 0.4524
# f1_score: 0.4749
# roc_auc: 0.5124
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5433
# recall: 0.4051
# f1_score: 0.4409
# roc_auc: 0.5137
# Cross-validation metrics:
# accuracy: 0.4996
# precision: 0.5348
# recall: 0.4158
# f1_score: 0.4442
# roc_auc: 0.5126
# Generation 28
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5175
# precision: 0.5491
# recall: 0.4723
# f1_score: 0.4981
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5077
# precision: 0.5401
# recall: 0.4570
# f1_score: 0.4746
# roc_auc: 0.5138
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5530
# recall: 0.4414
# f1_score: 0.4648
# roc_auc: 0.5224
# Cross-validation metrics:
# accuracy: 0.5056
# precision: 0.5364
# recall: 0.4730
# f1_score: 0.4700
# roc_auc: 0.5170
# Cross-validation metrics:
# accuracy: 0.5051
# precision: 0.5361
# recall: 0.4584
# f1_score: 0.4664
# roc_auc: 0.5177
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5141
# precision: 0.5458
# recall: 0.4732
# f1_score: 0.4876
# roc_auc: 0.5181
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Generation 29
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5346
# recall: 0.4468
# f1_score: 0.4756
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5030
# precision: 0.5347
# recall: 0.4238
# f1_score: 0.4630
# roc_auc: 0.5081
# Cross-validation metrics:
# accuracy: 0.5175
# precision: 0.5491
# recall: 0.4723
# f1_score: 0.4981
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5150
# precision: 0.5525
# recall: 0.4877
# f1_score: 0.4998
# roc_auc: 0.5247
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5524
# recall: 0.4793
# f1_score: 0.4786
# roc_auc: 0.5175
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5413
# recall: 0.4206
# f1_score: 0.4458
# roc_auc: 0.5310
# Generation 30
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5413
# recall: 0.4206
# f1_score: 0.4458
# roc_auc: 0.5310
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Cross-validation metrics:
# accuracy: 0.5132
# precision: 0.5438
# recall: 0.4856
# f1_score: 0.4766
# roc_auc: 0.5125
# Cross-validation metrics:
# accuracy: 0.5175
# precision: 0.5491
# recall: 0.4723
# f1_score: 0.4981
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5524
# recall: 0.4793
# f1_score: 0.4786
# roc_auc: 0.5175
# Cross-validation metrics:
# accuracy: 0.5056
# precision: 0.5364
# recall: 0.4730
# f1_score: 0.4700
# roc_auc: 0.5170
# Cross-validation metrics:
# accuracy: 0.5171
# precision: 0.5568
# recall: 0.4616
# f1_score: 0.4804
# roc_auc: 0.5249
# Cross-validation metrics:
# accuracy: 0.5167
# precision: 0.5542
# recall: 0.4629
# f1_score: 0.4750
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Generation 31
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5335
# recall: 0.4593
# f1_score: 0.4758
# roc_auc: 0.5191
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5504
# recall: 0.4992
# f1_score: 0.5111
# roc_auc: 0.5237
# Cross-validation metrics:
# accuracy: 0.5021
# precision: 0.5327
# recall: 0.4403
# f1_score: 0.4567
# roc_auc: 0.5136
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5438
# recall: 0.4417
# f1_score: 0.4699
# roc_auc: 0.5227
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5264
# recall: 0.4525
# f1_score: 0.4599
# roc_auc: 0.5174
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5413
# recall: 0.4206
# f1_score: 0.4458
# roc_auc: 0.5310
# Cross-validation metrics:
# accuracy: 0.4991
# precision: 0.5340
# recall: 0.4320
# f1_score: 0.4580
# roc_auc: 0.5203
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Cross-validation metrics:
# accuracy: 0.5141
# precision: 0.5440
# recall: 0.4970
# f1_score: 0.4993
# roc_auc: 0.5233
# Generation 32
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5407
# recall: 0.4919
# f1_score: 0.4974
# roc_auc: 0.5201
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5081
# precision: 0.5450
# recall: 0.4473
# f1_score: 0.4630
# roc_auc: 0.5186
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5281
# recall: 0.4306
# f1_score: 0.4564
# roc_auc: 0.5299
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5367
# recall: 0.5001
# f1_score: 0.5067
# roc_auc: 0.5132
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5439
# recall: 0.5076
# f1_score: 0.5180
# roc_auc: 0.5230
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5432
# recall: 0.5377
# f1_score: 0.5275
# roc_auc: 0.5218
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5442
# recall: 0.4511
# f1_score: 0.4645
# roc_auc: 0.5255
# Generation 33
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5387
# recall: 0.4785
# f1_score: 0.4746
# roc_auc: 0.5232
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5466
# recall: 0.5092
# f1_score: 0.5186
# roc_auc: 0.5276
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5439
# recall: 0.5076
# f1_score: 0.5180
# roc_auc: 0.5230
# Cross-validation metrics:
# accuracy: 0.5248
# precision: 0.5534
# recall: 0.5141
# f1_score: 0.5165
# roc_auc: 0.5228
# Cross-validation metrics:
# accuracy: 0.5004
# precision: 0.5325
# recall: 0.4441
# f1_score: 0.4556
# roc_auc: 0.5240
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5458
# recall: 0.5013
# f1_score: 0.5113
# roc_auc: 0.5227
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5034
# precision: 0.5455
# recall: 0.4064
# f1_score: 0.4454
# roc_auc: 0.5203
# Generation 34
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.4962
# precision: 0.5275
# recall: 0.4408
# f1_score: 0.4505
# roc_auc: 0.5102
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5458
# recall: 0.5013
# f1_score: 0.5113
# roc_auc: 0.5227
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5501
# recall: 0.4393
# f1_score: 0.4635
# roc_auc: 0.5352
# Cross-validation metrics:
# accuracy: 0.5004
# precision: 0.5325
# recall: 0.4441
# f1_score: 0.4556
# roc_auc: 0.5240
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5387
# recall: 0.4785
# f1_score: 0.4746
# roc_auc: 0.5232
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5546
# recall: 0.4236
# f1_score: 0.4590
# roc_auc: 0.5289
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5371
# recall: 0.4762
# f1_score: 0.4799
# roc_auc: 0.5247
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5350
# recall: 0.5113
# f1_score: 0.5108
# roc_auc: 0.5208
# Generation 35
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5038
# precision: 0.5264
# recall: 0.4525
# f1_score: 0.4599
# roc_auc: 0.5174
# Cross-validation metrics:
# accuracy: 0.5192
# precision: 0.5447
# recall: 0.5453
# f1_score: 0.5366
# roc_auc: 0.5176
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5115
# precision: 0.5387
# recall: 0.4785
# f1_score: 0.4746
# roc_auc: 0.5232
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5407
# recall: 0.4919
# f1_score: 0.4974
# roc_auc: 0.5201
# Cross-validation metrics:
# accuracy: 0.5214
# precision: 0.5580
# recall: 0.4991
# f1_score: 0.4906
# roc_auc: 0.5259
# Cross-validation metrics:
# accuracy: 0.5107
# precision: 0.5501
# recall: 0.4393
# f1_score: 0.4635
# roc_auc: 0.5352
# Cross-validation metrics:
# accuracy: 0.5085
# precision: 0.5425
# recall: 0.4460
# f1_score: 0.4589
# roc_auc: 0.5266
# Generation 36
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5145
# precision: 0.5463
# recall: 0.4684
# f1_score: 0.4819
# roc_auc: 0.5224
# Cross-validation metrics:
# accuracy: 0.5214
# precision: 0.5369
# recall: 0.5525
# f1_score: 0.5361
# roc_auc: 0.5151
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5171
# precision: 0.5410
# recall: 0.5120
# f1_score: 0.5107
# roc_auc: 0.5213
# Cross-validation metrics:
# accuracy: 0.5252
# precision: 0.5584
# recall: 0.5119
# f1_score: 0.5120
# roc_auc: 0.5172
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5378
# recall: 0.4447
# f1_score: 0.4690
# roc_auc: 0.5229
# Cross-validation metrics:
# accuracy: 0.5137
# precision: 0.5470
# recall: 0.4797
# f1_score: 0.4706
# roc_auc: 0.5204
# Generation 37
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5214
# precision: 0.5369
# recall: 0.5525
# f1_score: 0.5361
# roc_auc: 0.5151
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5407
# recall: 0.4919
# f1_score: 0.4974
# roc_auc: 0.5201
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5394
# recall: 0.4905
# f1_score: 0.5031
# roc_auc: 0.5186
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5047
# precision: 0.5378
# recall: 0.4447
# f1_score: 0.4690
# roc_auc: 0.5229
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5352
# recall: 0.4421
# f1_score: 0.4707
# roc_auc: 0.5102
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5278
# recall: 0.4555
# f1_score: 0.4632
# roc_auc: 0.5147
# Generation 38
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5214
# precision: 0.5369
# recall: 0.5525
# f1_score: 0.5361
# roc_auc: 0.5151
# Cross-validation metrics:
# accuracy: 0.4962
# precision: 0.5275
# recall: 0.4408
# f1_score: 0.4505
# roc_auc: 0.5102
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5392
# recall: 0.5068
# f1_score: 0.5049
# roc_auc: 0.5170
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5394
# recall: 0.4905
# f1_score: 0.5031
# roc_auc: 0.5186
# Cross-validation metrics:
# accuracy: 0.5162
# precision: 0.5529
# recall: 0.5064
# f1_score: 0.4906
# roc_auc: 0.5273
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5278
# recall: 0.4555
# f1_score: 0.4632
# roc_auc: 0.5147
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Generation 39
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5162
# precision: 0.5529
# recall: 0.5064
# f1_score: 0.4906
# roc_auc: 0.5273
# Cross-validation metrics:
# accuracy: 0.5060
# precision: 0.5352
# recall: 0.4421
# f1_score: 0.4707
# roc_auc: 0.5102
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5499
# recall: 0.4803
# f1_score: 0.4844
# roc_auc: 0.5292
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5482
# recall: 0.4411
# f1_score: 0.4696
# roc_auc: 0.5183
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5394
# recall: 0.4905
# f1_score: 0.5031
# roc_auc: 0.5186
# Cross-validation metrics:
# accuracy: 0.5111
# precision: 0.5689
# recall: 0.4241
# f1_score: 0.4459
# roc_auc: 0.5183
# Generation 40
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5162
# precision: 0.5529
# recall: 0.5064
# f1_score: 0.4906
# roc_auc: 0.5273
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5352
# recall: 0.4405
# f1_score: 0.4527
# roc_auc: 0.5106
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5394
# recall: 0.4905
# f1_score: 0.5031
# roc_auc: 0.5186
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5561
# recall: 0.4539
# f1_score: 0.4825
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5145
# precision: 0.5421
# recall: 0.5302
# f1_score: 0.5186
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5261
# precision: 0.5559
# recall: 0.5240
# f1_score: 0.5208
# roc_auc: 0.5284
# Cross-validation metrics:
# accuracy: 0.5132
# precision: 0.5361
# recall: 0.5123
# f1_score: 0.5119
# roc_auc: 0.5204
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Generation 41
# Cross-validation metrics:
# accuracy: 0.5145
# precision: 0.5421
# recall: 0.5302
# f1_score: 0.5186
# roc_auc: 0.5156
# Cross-validation metrics:
# accuracy: 0.5017
# precision: 0.5356
# recall: 0.4555
# f1_score: 0.4708
# roc_auc: 0.5076
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5402
# recall: 0.5097
# f1_score: 0.4900
# roc_auc: 0.5183
# Cross-validation metrics:
# accuracy: 0.5282
# precision: 0.5559
# recall: 0.5393
# f1_score: 0.5356
# roc_auc: 0.5326
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5132
# precision: 0.5361
# recall: 0.5123
# f1_score: 0.5119
# roc_auc: 0.5204
# Cross-validation metrics:
# accuracy: 0.5026
# precision: 0.5352
# recall: 0.4405
# f1_score: 0.4527
# roc_auc: 0.5106
# Generation 42
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5286
# recall: 0.5235
# f1_score: 0.5108
# roc_auc: 0.5037
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5043
# precision: 0.5283
# recall: 0.4676
# f1_score: 0.4911
# roc_auc: 0.5066
# Cross-validation metrics:
# accuracy: 0.4970
# precision: 0.5265
# recall: 0.4817
# f1_score: 0.4883
# roc_auc: 0.5064
# Cross-validation metrics:
# accuracy: 0.5090
# precision: 0.5465
# recall: 0.4657
# f1_score: 0.4669
# roc_auc: 0.5137
# Cross-validation metrics:
# accuracy: 0.5064
# precision: 0.5481
# recall: 0.4472
# f1_score: 0.4604
# roc_auc: 0.5163
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5436
# recall: 0.4719
# f1_score: 0.4847
# roc_auc: 0.5168
# Generation 43
# Cross-validation metrics:
# accuracy: 0.5179
# precision: 0.5461
# recall: 0.5255
# f1_score: 0.5151
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5158
# precision: 0.5427
# recall: 0.5215
# f1_score: 0.5110
# roc_auc: 0.5166
# Cross-validation metrics:
# accuracy: 0.5132
# precision: 0.5314
# recall: 0.5363
# f1_score: 0.5311
# roc_auc: 0.5197
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5555
# recall: 0.4866
# f1_score: 0.4866
# roc_auc: 0.5086
# Cross-validation metrics:
# accuracy: 0.5295
# precision: 0.5481
# recall: 0.5512
# f1_score: 0.5408
# roc_auc: 0.5345
# Cross-validation metrics:
# accuracy: 0.5226
# precision: 0.5621
# recall: 0.4973
# f1_score: 0.4908
# roc_auc: 0.5271
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5632
# recall: 0.4953
# f1_score: 0.4888
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5436
# recall: 0.4719
# f1_score: 0.4847
# roc_auc: 0.5168
# Cross-validation metrics:
# accuracy: 0.5248
# precision: 0.5532
# recall: 0.5277
# f1_score: 0.5270
# roc_auc: 0.5203
# Cross-validation metrics:
# accuracy: 0.5261
# precision: 0.5523
# recall: 0.5140
# f1_score: 0.5219
# roc_auc: 0.5240
# Generation 44
# Cross-validation metrics:
# accuracy: 0.5132
# precision: 0.5528
# recall: 0.4396
# f1_score: 0.4722
# roc_auc: 0.5154
# Cross-validation metrics:
# accuracy: 0.5098
# precision: 0.5316
# recall: 0.4368
# f1_score: 0.4476
# roc_auc: 0.5254
# Cross-validation metrics:
# accuracy: 0.5056
# precision: 0.5388
# recall: 0.4260
# f1_score: 0.4540
# roc_auc: 0.5167
# Cross-validation metrics:
# accuracy: 0.5073
# precision: 0.5408
# recall: 0.4279
# f1_score: 0.4450
# roc_auc: 0.5155
# Cross-validation metrics:
# accuracy: 0.5090
# ...
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5624
# recall: 0.4006
# f1_score: 0.4334
# roc_auc: 0.5173
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5681
# recall: 0.3677
# f1_score: 0.3990
# roc_auc: 0.5208
# Cross-validation metrics:
# accuracy: 0.5187
# precision: 0.5564
# recall: 0.4366
# f1_score: 0.4511
# roc_auc: 0.5275
# Cross-validation metrics:
# accuracy: 0.5086
# precision: 0.5557
# recall: 0.3718
# f1_score: 0.3991
# roc_auc: 0.5136
# Cross-validation metrics:
# accuracy: 0.5033
# precision: 0.5555
# recall: 0.3489
# f1_score: 0.3856
# roc_auc: 0.5141
# Cross-validation metrics:
# accuracy: 0.5113
# precision: 0.5595
# recall: 0.3967
# f1_score: 0.4280
# roc_auc: 0.5148
# Cross-validation metrics:
# accuracy: 0.5162
# precision: 0.5651
# recall: 0.3960
# f1_score: 0.4258
# roc_auc: 0.5165
# Cross-validation metrics:
# accuracy: 0.5103
# precision: 0.5619
# recall: 0.3585
# f1_score: 0.3913
# roc_auc: 0.5252
# Generation 39
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5542
# recall: 0.3983
# f1_score: 0.4343
# roc_auc: 0.5218
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5044
# precision: 0.5439
# recall: 0.3757
# f1_score: 0.4076
# roc_auc: 0.5183
# Cross-validation metrics:
# accuracy: 0.5194
# precision: 0.5624
# recall: 0.4301
# f1_score: 0.4468
# roc_auc: 0.5256
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5622
# recall: 0.3869
# f1_score: 0.4229
# roc_auc: 0.5227
# Cross-validation metrics:
# accuracy: 0.5148
# precision: 0.5577
# recall: 0.4061
# f1_score: 0.4285
# roc_auc: 0.5136
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5624
# recall: 0.4006
# f1_score: 0.4334
# roc_auc: 0.5173
# Cross-validation metrics:
# accuracy: 0.5148
# precision: 0.5695
# recall: 0.3804
# f1_score: 0.4161
# roc_auc: 0.5180
# Cross-validation metrics:
# accuracy: 0.5155
# precision: 0.5658
# recall: 0.3909
# f1_score: 0.4234
# roc_auc: 0.5229
# Generation 40
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5553
# recall: 0.3869
# f1_score: 0.4207
# roc_auc: 0.5165
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.4984
# precision: 0.5451
# recall: 0.3380
# f1_score: 0.3776
# roc_auc: 0.5087
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5622
# recall: 0.3869
# f1_score: 0.4229
# roc_auc: 0.5227
# Cross-validation metrics:
# accuracy: 0.5110
# precision: 0.5604
# recall: 0.3812
# f1_score: 0.4118
# roc_auc: 0.5179
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5113
# precision: 0.5562
# recall: 0.3936
# f1_score: 0.4204
# roc_auc: 0.5228
# Cross-validation metrics:
# accuracy: 0.5148
# precision: 0.5577
# recall: 0.4061
# f1_score: 0.4285
# roc_auc: 0.5136
# Generation 41
# Cross-validation metrics:
# accuracy: 0.5113
# precision: 0.5616
# recall: 0.3880
# f1_score: 0.4199
# roc_auc: 0.5136
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5211
# precision: 0.5767
# recall: 0.4136
# f1_score: 0.4379
# roc_auc: 0.5187
# Cross-validation metrics:
# accuracy: 0.5148
# precision: 0.5577
# recall: 0.4061
# f1_score: 0.4285
# roc_auc: 0.5136
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5474
# recall: 0.4128
# f1_score: 0.4348
# roc_auc: 0.5157
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5528
# recall: 0.4147
# f1_score: 0.4461
# roc_auc: 0.5136
# Generation 42
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5159
# precision: 0.5764
# recall: 0.3960
# f1_score: 0.4263
# roc_auc: 0.5245
# Cross-validation metrics:
# accuracy: 0.5145
# precision: 0.5544
# recall: 0.4033
# f1_score: 0.4249
# roc_auc: 0.5233
# Cross-validation metrics:
# accuracy: 0.5106
# precision: 0.5614
# recall: 0.4044
# f1_score: 0.4333
# roc_auc: 0.5074
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5086
# precision: 0.5547
# recall: 0.3823
# f1_score: 0.4157
# roc_auc: 0.5114
# Cross-validation metrics:
# accuracy: 0.5065
# precision: 0.5484
# recall: 0.3877
# f1_score: 0.4165
# roc_auc: 0.5223
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5099
# precision: 0.5656
# recall: 0.3723
# f1_score: 0.4061
# roc_auc: 0.5144
# Generation 43
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5099
# precision: 0.5652
# recall: 0.3863
# f1_score: 0.4211
# roc_auc: 0.5173
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5065
# precision: 0.5484
# recall: 0.3877
# f1_score: 0.4165
# roc_auc: 0.5223
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5110
# precision: 0.5580
# recall: 0.3942
# f1_score: 0.4206
# roc_auc: 0.5194
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5141
# precision: 0.5640
# recall: 0.3934
# f1_score: 0.4237
# roc_auc: 0.5148
# Cross-validation metrics:
# accuracy: 0.5152
# precision: 0.5635
# recall: 0.4056
# f1_score: 0.4306
# roc_auc: 0.5096
# Generation 44
# Cross-validation metrics:
# accuracy: 0.5061
# precision: 0.5518
# recall: 0.3724
# f1_score: 0.3981
# roc_auc: 0.5084
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5075
# precision: 0.5480
# recall: 0.3879
# f1_score: 0.4162
# roc_auc: 0.5137
# Cross-validation metrics:
# accuracy: 0.5159
# precision: 0.5736
# recall: 0.4053
# f1_score: 0.4346
# roc_auc: 0.5158
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5671
# recall: 0.3604
# f1_score: 0.3986
# roc_auc: 0.5260
# Generation 45
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5061
# precision: 0.5445
# recall: 0.3955
# f1_score: 0.4166
# roc_auc: 0.5187
# Cross-validation metrics:
# accuracy: 0.5173
# precision: 0.5656
# recall: 0.4147
# f1_score: 0.4483
# roc_auc: 0.5200
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5671
# recall: 0.3604
# f1_score: 0.3986
# roc_auc: 0.5260
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5197
# precision: 0.5790
# recall: 0.3908
# f1_score: 0.4119
# roc_auc: 0.5213
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5065
# precision: 0.5484
# recall: 0.3877
# f1_score: 0.4165
# roc_auc: 0.5223
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Generation 46
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5671
# recall: 0.3604
# f1_score: 0.3986
# roc_auc: 0.5260
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5096
# precision: 0.5609
# recall: 0.3733
# f1_score: 0.4076
# roc_auc: 0.5073
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5743
# recall: 0.3861
# f1_score: 0.4123
# roc_auc: 0.5154
# Cross-validation metrics:
# accuracy: 0.5120
# precision: 0.5587
# recall: 0.3919
# f1_score: 0.4179
# roc_auc: 0.5137
# Cross-validation metrics:
# accuracy: 0.5054
# precision: 0.5445
# recall: 0.3905
# f1_score: 0.4018
# roc_auc: 0.5152
# Generation 47
# Cross-validation metrics:
# accuracy: 0.5183
# precision: 0.5743
# recall: 0.3946
# f1_score: 0.4121
# roc_auc: 0.5212
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5839
# recall: 0.3908
# f1_score: 0.4232
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Cross-validation metrics:
# accuracy: 0.5232
# precision: 0.5650
# recall: 0.4384
# f1_score: 0.4612
# roc_auc: 0.5184
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5671
# recall: 0.3604
# f1_score: 0.3986
# roc_auc: 0.5260
# Cross-validation metrics:
# accuracy: 0.5138
# precision: 0.5757
# recall: 0.3632
# f1_score: 0.3960
# roc_auc: 0.5175
# Cross-validation metrics:
# accuracy: 0.5089
# precision: 0.5547
# recall: 0.3871
# f1_score: 0.4185
# roc_auc: 0.5133
# Cross-validation metrics:
# accuracy: 0.5208
# precision: 0.5776
# recall: 0.4042
# f1_score: 0.4357
# roc_auc: 0.5384
# Cross-validation metrics:
# accuracy: 0.5180
# precision: 0.5788
# recall: 0.3896
# f1_score: 0.4242
# roc_auc: 0.5242
# Generation 48
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Cross-validation metrics:
# accuracy: 0.5138
# precision: 0.5659
# recall: 0.3914
# f1_score: 0.4206
# roc_auc: 0.5111
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5264
# precision: 0.5743
# recall: 0.4134
# f1_score: 0.4405
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5131
# precision: 0.5671
# recall: 0.3604
# f1_score: 0.3986
# roc_auc: 0.5260
# Cross-validation metrics:
# accuracy: 0.5201
# precision: 0.5731
# recall: 0.4157
# f1_score: 0.4377
# roc_auc: 0.5356
# Cross-validation metrics:
# accuracy: 0.5176
# precision: 0.5645
# recall: 0.4044
# f1_score: 0.4278
# roc_auc: 0.5239
# Cross-validation metrics:
# accuracy: 0.5162
# precision: 0.5661
# recall: 0.3964
# f1_score: 0.4286
# roc_auc: 0.5127
# Cross-validation metrics:
# accuracy: 0.5127
# precision: 0.5540
# recall: 0.4289
# f1_score: 0.4540
# roc_auc: 0.5108
# Generation 49
# Cross-validation metrics:
# accuracy: 0.5271
# precision: 0.5906
# recall: 0.4175
# f1_score: 0.4466
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5288
# precision: 0.5836
# recall: 0.4107
# f1_score: 0.4490
# roc_auc: 0.5312
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5723
# recall: 0.4306
# f1_score: 0.4618
# roc_auc: 0.5180
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5681
# recall: 0.3677
# f1_score: 0.3990
# roc_auc: 0.5208
# Cross-validation metrics:
# accuracy: 0.5138
# precision: 0.5591
# recall: 0.4091
# f1_score: 0.4448
# roc_auc: 0.5159
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5264
# precision: 0.5743
# recall: 0.4134
# f1_score: 0.4405
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5152
# precision: 0.5703
# recall: 0.4110
# f1_score: 0.4388
# roc_auc: 0.5158
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5817
# recall: 0.4030
# f1_score: 0.4365
# roc_auc: 0.5303
# Generation 50
# Cross-validation metrics:
# accuracy: 0.4960
# precision: 0.5336
# recall: 0.3521
# f1_score: 0.3842
# roc_auc: 0.5190
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5271
# precision: 0.5906
# recall: 0.4175
# f1_score: 0.4466
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5288
# precision: 0.5836
# recall: 0.4107
# f1_score: 0.4490
# roc_auc: 0.5312
# Cross-validation metrics:
# accuracy: 0.5152
# precision: 0.5703
# recall: 0.4110
# f1_score: 0.4388
# roc_auc: 0.5158
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5681
# recall: 0.3677
# f1_score: 0.3990
# roc_auc: 0.5208
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5723
# recall: 0.4306
# f1_score: 0.4618
# roc_auc: 0.5180
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5264
# precision: 0.5743
# recall: 0.4134
# f1_score: 0.4405
# roc_auc: 0.5319
# Cross-validation metrics:
# accuracy: 0.5183
# precision: 0.5711
# recall: 0.3772
# f1_score: 0.4102
# roc_auc: 0.5305
# Cross-validation metrics:
# accuracy: 0.5288
# precision: 0.5836
# recall: 0.4107
# f1_score: 0.4490
# roc_auc: 0.5312
# Cross-validation metrics:
# accuracy: 0.5239
# precision: 0.5933
# recall: 0.3916
# f1_score: 0.4254
# roc_auc: 0.5286
# Cross-validation metrics:
# accuracy: 0.5271
# precision: 0.5906
# recall: 0.4175
# f1_score: 0.4466
# roc_auc: 0.5265
# Cross-validation metrics:
# accuracy: 0.5260
# precision: 0.5889
# recall: 0.4111
# f1_score: 0.4431
# roc_auc: 0.5251
# Cross-validation metrics:
# accuracy: 0.5124
# precision: 0.5681
# recall: 0.3677
# f1_score: 0.3990
# roc_auc: 0.5208
# Cross-validation metrics:
# accuracy: 0.5152
# precision: 0.5703
# recall: 0.4110
# f1_score: 0.4388
# roc_auc: 0.5158
# Cross-validation metrics:
# accuracy: 0.5152
# precision: 0.5659
# recall: 0.4135
# f1_score: 0.4479
# roc_auc: 0.5195
# Cross-validation metrics:
# accuracy: 0.5267
# precision: 0.5819
# recall: 0.4188
# f1_score: 0.4490
# roc_auc: 0.5272
# Cross-validation metrics:
# accuracy: 0.5068
# precision: 0.5605
# recall: 0.3671
# f1_score: 0.4005
# roc_auc: 0.5140
# Cross-validation metrics:
# accuracy: 0.5222
# precision: 0.5723
# recall: 0.4306
# f1_score: 0.4618
# roc_auc: 0.5180
# ✅ Best features for AMZN: ['HT_PHASOR_quadrature', 'TRANGE', 'STOCH_fastd', 'RSI', 'MOM', 'ADX', 'MIDPRICE', 'STOCH_fastk', 'CCI', 'DEMA', 'MACD_hist', 'HT_DCPHASE', 'BB_lower', 'AROON_UP', 'WMA', 'STOCH_slowd', 'HT_DCPERIOD', 'AVGPRICE', 'MINUS_DI', 'APO', 'T3', 'PLUS_DI']
# Cross-validation metrics:
# accuracy: 0.5037
# precision: 0.5572
# recall: 0.3398
# f1_score: 0.3714
# roc_auc: 0.5265
# Final model retrained on all data saved to xgboost_AMZN_new.joblib
# 📊 Final Metrics for AMZN: {'accuracy': 0.5036649214659685, 'precision': 0.557156177774513, 'recall': 0.33977504493665284, 'f1_score': 0.37137532626601183, 'roc_auc': 0.5264889429822439}
