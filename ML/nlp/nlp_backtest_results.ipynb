# %%
from backtest_nlp import backtest_nlp_signals

# ----------------------------------------
# 2. Parameters
# ----------------------------------------
ticker = "TSLA"
start_date = "2024-08-01"
end_date = "2025-02-19"
window_size = 15
API_KEY = 'NL9PDOM5JWRPAT9O'  # Replace with your actual key

# ----------------------------------------
# 3. Run the NLP backtest
# ----------------------------------------
merged_df, cm, acc = backtest_nlp_signals(
    ticker=ticker,
    start_date=start_date,
    end_date=end_date,
    api_key=API_KEY,
    window=window_size
)

# ----------------------------------------
# 4. Preview merged result
# ----------------------------------------
print("\n--- Merged DataFrame (head) ---")
print(merged_df.head())
# Out:
# Total number of articles fetched: 602
# ...
